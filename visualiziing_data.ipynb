# %%
import numpy as np
import pandas as pd

# %%
# Load the dataset
dortmund = pd.read_csv('dataset/Dortmund_features.csv')

# Display the first few rows (optional)
dortmund.head()

# Get the number of rows and columns
print("Number of patients:", dortmund.shape[0])
print("Number of features:", dortmund.shape[1])
# Out:
# Number of patients: 600
# Number of features: 148

# %%
# Load the dataset
lemon = pd.read_csv('dataset/Lemon_features.csv')

# Display the first few rows (optional)
lemon.head()

# Get the number of rows and columns
print("Number of patients:", lemon.shape[0])
print("Number of features:", lemon.shape[1])
# Out:
# Number of patients: 190
# Number of features: 148
